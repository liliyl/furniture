# %%
import time
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

import skimage

import cPickle as pickle

# %%
import re
import collections
from nltk.corpus import stopwords 
from nltk import word_tokenize
#from nltk.stem import PorterStemmer
#from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %%
from image_processing import get_paths

# %%
import gensim
from gensim import corpora, models, similarities

# %% [markdown]
# # clean text data
# * furniture_id: strip & str()
# * price: string with $ to float
# * features from list to string
# * add description & features to one string

# %%
sofa_df = pd.read_json('wayfair/sofa.json')

# %%
sofa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 480 entries, 0.0 to 99.0
# Data columns (total 15 columns):
# category                480 non-null object
# colors                  480 non-null object
# description             359 non-null object
# features                480 non-null object
# image_links_all         480 non-null object
# image_links_by_color    480 non-null object
# manufacturer            480 non-null object
# price                   480 non-null object
# product_id              480 non-null object
# rating_avg              420 non-null float64
# rating_count            420 non-null float64
# specs                   470 non-null object
# title                   480 non-null object
# url                     480 non-null object
# website                 480 non-null object
# dtypes: float64(2), object(13)
# memory usage: 60.0+ KB

# %%
sofa_df.head().T
# Out:
#                                                                     0    \
# category                                                           sofa
# colors                   [Cobblestone, Café, Mocha, Sage, Salsa, Stone]
# description           Add a touch of comfort and style to your home ...
# features              [\nFeatures\n\nHarvest collection\nMaterial: 1...
# image_links_all       [https://secure.img2.wfrcdn.com/lf/49/hash/266...
# image_links_by_color  {u'Stone': [u'https://secure.img2.wfrcdn.com/l...
# manufacturer                                 Signature Design by Ashley
# price                                                           $357.99
# product_id                                                      GNT3224
# rating_avg                                                          4.4
# rating_count                                                        115
# specs                 \nWeights & Dimensions\n\n\n\n            Over...
# title                                                      Harvest Sofa
# url                   http://www.wayfair.com/Harvest-Sofa-7500-GNT32...
# website                                                         wayfair
#
#                                                                     1    \
# category                                                           sofa
# colors                [Blue Linen / Chevron, Blue Linen / Greek Key,...
# description           Sleeping on the sofa has never been so chic. S...
# features              [\nFeatures\n\nMaterial: 100% Polyester Linen\...
# image_links_all       [https://secure.img1.wfrcdn.com/lf/49/hash/338...
# image_links_by_color  {u'Blue Linen / Chevron': [u'https://secure.im...
# manufacturer                                                Mercury Row
# price                                                           $529.99
# product_id                                                     MCRR1650
# rating_avg                                                          4.1
# rating_count                                                        189
# specs                 \nWeights & Dimensions\nSeat Cushion\n\n\n    ...
# title                                          Convertible Sleeper Sofa
# url                   http://www.wayfair.com/Convertible-Sleeper-Sof...
# website                                                         wayfair
#
#                                                                     10   \
# category                                                           sofa
# colors                            [Purple, Red, Brown, Dark Grey, Grey]
# description           This luxurious sofa merging with style and ele...
# features              [\nFeatures\n\nCarthusia collection\nRubberwoo...
# image_links_all       [https://secure.img2.wfrcdn.com/lf/49/hash/296...
# image_links_by_color  {u'Purple': [u'https://secure.img2.wfrcdn.com/...
# manufacturer                                             Kingstown Home
# price                                                           $829.99
# product_id                                                     KMDS1431
# rating_avg                                                          4.5
# rating_count                                                         91
# specs                 \nWeights & Dimensions\nSeat Cushion\n\n\n    ...
# title                                                    Carthusia Sofa
# url                   http://www.wayfair.com/Kingstown-Home-Carthusi...
# website                                                         wayfair
#
#                                                                     100  \
# category                                                           sofa
# colors                                         [Ash, Graphite, Natural]
# description           tion’s mid-century modern design is masterfull...
# features              [\nFeatures\n\nCovered in durable, easy-to-cle...
# image_links_all       [https://secure.img1.wfrcdn.com/lf/49/hash/384...
# image_links_by_color  {u'Graphite': [u'https://secure.img1.wfrcdn.co...
# manufacturer                                           Carolina Accents
# price                                                           $189.99
# product_id                                                      ENT1245
# rating_avg                                                          4.5
# rating_count                                                         77
# specs                 \nWeights & Dimensions\n\n\n\n            Over...
# title                                                 Makenzie Loveseat
# url                   http://www.wayfair.com/Carolina-Accents-Makenz...
# website                                                         wayfair
#
#                                                                     101
# category                                                           sofa
# colors                [Greenwich Ivory, Greenwich Pecan, Greenwich L...
# description           Casual and comfy, the Smith Loveseat offers an...
# features              [\nFeatures\n\nLoose back and seat cushions\nH...
# image_links_all       [https://secure.img1.wfrcdn.com/lf/49/hash/308...
# image_links_by_color  {u'Greenwich Pecan': [u'https://secure.img1.wf...
# manufacturer                                              Andover Mills
# price                                                           $289.99
# product_id                                                     ANDO1550
# rating_avg                                                          4.5
# rating_count                                                         10
# specs                 \nWeights & Dimensions\n\n\n\n            Over...
# title                                                    Smith Loveseat
# url                   http://www.wayfair.com/Smith-Loveseat-ANDO1550...
# website                                                         wayfair

# %%
def clean_text_data(df, sofa=False):
    df['product_id'] = df['product_id'].apply(lambda x: x.strip())
    df['price'] = df['price'].apply(lambda x:float(x.strip('$').replace(',','').split()[0]))
    df['features'] = df['features'].apply(lambda x: '\n'.join(x) if type(x)==list else x)
    df['description'] = df['description'].apply(lambda x: '\n'.join(x) if type(x)==list else x)
    df['description'][df['description'].isnull()] = ''
    df['description_all'] = df['description'] + '\n' + df['features']
    if sofa:
        df = df.set_index('product_id')
    return df

# %%
start = time.time()
sofa_df = clean_text_data(sofa_df)
print time.time() - start
# Out:
# 0.0798678398132
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sofa_df[sofa_df['description_all'] == '\n'].product_id
# Out:
# 172     GUS1222
# 181      LF1136
# 207     GNT2290
# 229     BRH3913
# 320     BRH3828
# 364     ARA1325
# 388      LR1360
# 394     GNT2320
# 438    CTHM1159
# 451     GNT2526
# Name: product_id, dtype: object

# %%
sofa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 480 entries, 0.0 to 99.0
# Data columns (total 16 columns):
# category                480 non-null object
# colors                  480 non-null object
# description             480 non-null object
# features                480 non-null object
# image_links_all         480 non-null object
# image_links_by_color    480 non-null object
# manufacturer            480 non-null object
# price                   480 non-null float64
# product_id              480 non-null object
# rating_avg              420 non-null float64
# rating_count            420 non-null float64
# specs                   470 non-null object
# title                   480 non-null object
# url                     480 non-null object
# website                 480 non-null object
# description_all         480 non-null object
# dtypes: float64(3), object(13)
# memory usage: 63.8+ KB

# %%
sofa_df.head().T
# Out:
#                                                                     0    \
# category                                                           sofa
# colors                   [Cobblestone, Café, Mocha, Sage, Salsa, Stone]
# description           Add a touch of comfort and style to your home ...
# features              \nFeatures\n\nHarvest collection\nMaterial: 10...
# image_links_all       [https://secure.img2.wfrcdn.com/lf/49/hash/266...
# image_links_by_color  {u'Stone': [u'https://secure.img2.wfrcdn.com/l...
# manufacturer                                 Signature Design by Ashley
# price                                                            357.99
# product_id                                                      GNT3224
# rating_avg                                                          4.4
# rating_count                                                        115
# specs                 \nWeights & Dimensions\n\n\n\n            Over...
# title                                                      Harvest Sofa
# url                   http://www.wayfair.com/Harvest-Sofa-7500-GNT32...
# website                                                         wayfair
# description_all       Add a touch of comfort and style to your home ...
#
#                                                                     1    \
# category                                                           sofa
# colors                [Blue Linen / Chevron, Blue Linen / Greek Key,...
# description           Sleeping on the sofa has never been so chic. S...
# features              \nFeatures\n\nMaterial: 100% Polyester Linen\n...
# image_links_all       [https://secure.img1.wfrcdn.com/lf/49/hash/338...
# image_links_by_color  {u'Blue Linen / Chevron': [u'https://secure.im...
# manufacturer                                                Mercury Row
# price                                                            529.99
# product_id                                                     MCRR1650
# rating_avg                                                          4.1
# rating_count                                                        189
# specs                 \nWeights & Dimensions\nSeat Cushion\n\n\n    ...
# title                                          Convertible Sleeper Sofa
# url                   http://www.wayfair.com/Convertible-Sleeper-Sof...
# website                                                         wayfair
# description_all       Sleeping on the sofa has never been so chic. S...
#
#                                                                     10   \
# category                                                           sofa
# colors                            [Purple, Red, Brown, Dark Grey, Grey]
# description           This luxurious sofa merging with style and ele...
# features              \nFeatures\n\nCarthusia collection\nRubberwood...
# image_links_all       [https://secure.img2.wfrcdn.com/lf/49/hash/296...
# image_links_by_color  {u'Purple': [u'https://secure.img2.wfrcdn.com/...
# manufacturer                                             Kingstown Home
# price                                                            829.99
# product_id                                                     KMDS1431
# rating_avg                                                          4.5
# rating_count                                                         91
# specs                 \nWeights & Dimensions\nSeat Cushion\n\n\n    ...
# title                                                    Carthusia Sofa
# url                   http://www.wayfair.com/Kingstown-Home-Carthusi...
# website                                                         wayfair
# description_all       This luxurious sofa merging with style and ele...
#
#                                                                     100  \
# category                                                           sofa
# colors                                         [Ash, Graphite, Natural]
# description           tion’s mid-century modern design is masterfull...
# features              \nFeatures\n\nCovered in durable, easy-to-clea...
# image_links_all       [https://secure.img1.wfrcdn.com/lf/49/hash/384...
# image_links_by_color  {u'Graphite': [u'https://secure.img1.wfrcdn.co...
# manufacturer                                           Carolina Accents
# price                                                            189.99
# product_id                                                      ENT1245
# rating_avg                                                          4.5
# rating_count                                                         77
# specs                 \nWeights & Dimensions\n\n\n\n            Over...
# title                                                 Makenzie Loveseat
# url                   http://www.wayfair.com/Carolina-Accents-Makenz...
# website                                                         wayfair
# description_all       tion’s mid-century modern design is masterfull...
#
#                                                                     101
# category                                                           sofa
# colors                [Greenwich Ivory, Greenwich Pecan, Greenwich L...
# description           Casual and comfy, the Smith Loveseat offers an...
# features              \nFeatures\n\nLoose back and seat cushions\nHi...
# image_links_all       [https://secure.img1.wfrcdn.com/lf/49/hash/308...
# image_links_by_color  {u'Greenwich Pecan': [u'https://secure.img1.wf...
# manufacturer                                              Andover Mills
# price                                                            289.99
# product_id                                                     ANDO1550
# rating_avg                                                          4.5
# rating_count                                                         10
# specs                 \nWeights & Dimensions\n\n\n\n            Over...
# title                                                    Smith Loveseat
# url                   http://www.wayfair.com/Smith-Loveseat-ANDO1550...
# website                                                         wayfair
# description_all       Casual and comfy, the Smith Loveseat offers an...

# %%
sofa_df.to_json('wayfair/sofa_clean.json')

# %% [markdown]
# # TFIDF: description + features
# # tried default tokenizer & my own tokenizer with stemmer - seems to work similarly... can test again on more the whole model.  Can also test with different max_features & max_df.

# %%
X = sofa_df['description_all'][sofa_df['description_all'].notnull()]
tfidf = TfidfVectorizer(strip_accents='unicode', stop_words='english', max_df=0.8, 
                        max_features=5000, ngram_range = (1,2))
tfidf_matrix = tfidf.fit_transform(X).todense()

# %%
tfidf.get_feature_names()
# Out:
# [u'10',
#  u'100',
#  u'100 cotton',
#  u'100 dacron',
#  u'100 poly',
#  u'100 polyester',
#  u'100 sky',
#  u'12',
#  u'12 coil',
#  u'13',
#  u'13 gauge',
#  u'16',
#  u'18',
#  u'1oz',
#  u'1oz oz',
#  u'20',
#  u'20 cut',
#  u'21',
#  u'21 inches',
#  u'22',
#  u'22 inches',
#  u'25',
#  u'25 13',
#  u'28',
#  u'30',
#  u'30 day',
#  u'30 days',
#  u'32',
#  u'33',
#  u'34',
#  u'34 lbs',
#  u'36',
#  u'3a',
#  u'3a certified',
#  u'45',
#  u'45 inches',
#  u'50',
#  u'54',
#  u'576',
#  u'576 independently',
#  u'60',
#  u'600',
#  u'600 lbs',
#  u'600 pounds',
#  u'64',
#  u'65',
#  u'65 warning',
#  u'70',
#  u'70 plywood',
#  u'700',
#  u'700 pounds',
#  u'72',
#  u'75',
#  u'75 years',
#  u'90',
#  u'90 days',
#  u'95',
#  u'abbott',
#  u'abbyson',
#  u'abbyson living',
#  u'ability',
#  u'ac',
#  u'ac pacific',
#  u'accent',
#  u'accent chair',
#  u'accent chairs',
#  u'accent pillows',
#  u'accent toss',
#  u'accented',
#  u'accented beautifully',
#  u'accents',
#  u'accentuates',
#  u'accessorized',
#  u'accessorized matching',
#  u'accommodate',
#  u'accommodate people',
#  u'accommodates',
#  u'accommodates size',
#  u'acrylic',
#  u'actual',
#  u'actual room',
#  u'add',
#  u'add comfort',
#  u'add modern',
#  u'add sophistication',
#  u'add touch',
#  u'added',
#  u'added comfort',
#  u'added sleeping',
#  u'adding',
#  u'addition',
#  u'addition home',
#  u'addition living',
#  u'addition room',
#  u'additional',
#  u'additional comfort',
#  u'additional peace',
#  u'adds',
#  u'adds comfort',
#  u'adds elegance',
#  u'adds lasting',
#  u'adds look',
#  u'adds style',
#  u'adds visual',
#  u'adjustable',
#  u'adjustable headrest',
#  u'adjustment',
#  u'adorned',
#  u'adorned tufted',
#  u'affordable',
#  u'affordable solution',
#  u'afternoon',
#  u'ahfa',
#  u'ahfa standards',
#  u'aid',
#  u'aid design',
#  u'air',
#  u'air blown',
#  u'air nobility',
#  u'air quality',
#  u'alexa',
#  u'allow',
#  u'allowing',
#  u'allows',
#  u'allows multiple',
#  u'allows sit',
#  u'almond',
#  u'amanda',
#  u'america',
#  u'america features',
#  u'ample',
#  u'ample seating',
#  u'anchor',
#  u'anchor good',
#  u'andover',
#  u'andover mills',
#  u'angel',
#  u'angelo',
#  u'angelo home',
#  u'angle',
#  u'aniline',
#  u'aniline dyed',
#  u'anti',
#  u'anti sag',
#  u'apart',
#  u'appeal',
#  u'appealing',
#  u'appearance',
#  u'application',
#  u'application commercial',
#  u'application residential',
#  u'applied',
#  u'applied copper',
#  u'applied nail',
#  u'approved',
#  u'approved ahfa',
#  u'approved wearability',
#  u'area',
#  u'area easily',
#  u'area features',
#  u'area refreshing',
#  u'areas',
#  u'areas frame',
#  u'areas frames',
#  u'areas skillfully',
#  u'aries',
#  u'aristocrat',
#  u'aristocrat leather',
#  u'arm',
#  u'arm boxed',
#  u'arm covered',
#  u'arm design',
#  u'arm finished',
#  u'arm pillows',
#  u'arm rest',
#  u'arm toss',
#  u'arm weled',
#  u'armen',
#  u'armen living',
#  u'armless',
#  u'armrest',
#  u'armrests',
#  u'armrests convey',
#  u'arms',
#  u'arms arms',
#  u'arms artisan',
#  u'arms blended',
#  u'arms block',
#  u'arms button',
#  u'arms casual',
#  u'arms center',
#  u'arms corrugated',
#  u'arms create',
#  u'arms crisp',
#  u'arms features',
#  u'arms loose',
#  u'arms nail',
#  u'arms overstuffed',
#  u'arms pillow',
#  u'arms plush',
#  u'arms removable',
#  u'arms reversible',
#  u'arms sarah',
#  u'arms seat',
#  u'arms solid',
#  u'arms spacious',
#  u'arms style',
#  u'arms supportive',
#  u'arms throw',
#  u'arms tufted',
#  u'arms turned',
#  u'arms upholstered',
#  u'arms upholstery',
#  u'arms waterfall',
#  u'arms yes',
#  u'array',
#  u'array upholstery',
#  u'arrival',
#  u'arrival features',
#  u'artisan',
#  u'artisan crafted',
#  u'ash',
#  u'ashland',
#  u'ashley',
#  u'aspen',
#  u'assembled',
#  u'assembled actual',
#  u'assembled united',
#  u'assembly',
#  u'assembly arrival',
#  u'assembly breeze',
#  u'assembly manufactured',
#  u'assembly product',
#  u'assembly required',
#  u'assured',
#  u'assured quality',
#  u'atlanta',
#  u'attached',
#  u'attached cushions',
#  u'attached knife',
#  u'attached product',
#  u'attached seat',
#  u'attached sofa',
#  u'attachment',
#  u'attention',
#  u'attractive',
#  u'attractive features',
#  u'audrina',
#  u'audrina collection',
#  u'available',
#  u'available array',
#  u'available multiple',
#  u'available various',
#  u'available wide',
#  u'avery',
#  u'avery collection',
#  u'awaken',
#  u'awaken decor',
#  u'away',
#  u'away dust',
#  u'backrest',
#  u'backs',
#  u'backs arms',
#  u'backs pillows',
#  u'bags',
#  u'bailey',
#  u'bailey barley',
#  u'bailey charcoal',
#  u'bailey lagoon',
#  u'bailey mushroom',
#  u'bailey papyrus',
#  u'balance',
#  u'balance floor',
#  u'balanced',
#  u'bar',
#  u'bar added',
#  u'bar optimal',
#  u'bark',
#  u'bark microsuede',
#  u'barley',
#  u'barley blended',
#  u'barrister',
#  u'base',
#  u'base features',
#  u'base optimum',
#  u'based',
#  u'based cleaner',
#  u'based components',
#  u'based upholstery',
#  u'basic',
#  u'basic complements',
#  u'basis',
#  u'basis sit',
#  u'baxton',
#  u'baxton studio',
#  u'beans',
#  u'beans backs',
#  u'beans castor',
#  u'bearing',
#  u'bearing areas',
#  u'beautiful',
#  u'beautiful piece',
#  u'beautifully',
#  u'beautifully adorned',
#  u'beautifully shaped',
#  u'beauty',
#  u'beauty vintage',
#  u'bed',
#  u'bed frame',
#  u'bed position',
#  u'bed product',
#  u'bed sleeper',
#  u'bed touch',
#  u'bedroom',
#  u'beginning',
#  u'beginning sofa',
#  u'beige',
#  u'beige color',
#  u'beige linen',
#  u'belmont',
#  u'belongs',
#  u'bench',
#  u'beneath',
#  u'best',
#  u'best style',
#  u'best suits',
#  u'better',
#  u'better materials',
#  u'beyan',
#  u'bi',
#  u'bi cast',
#  u'big',
#  u'birch',
#  u'birch engineered',
#  u'birch wood',
#  u'birth',
#  u'birth defects',
#  u'black',
#  u'black arms',
#  u'black stained',
#  u'black wood',
#  u'blend',
#  u'blend accent',
#  u'blend assembly',
#  u'blend cushions',
#  u'blend eco',
#  u'blend structure',
#  u'blend upholstery',
#  u'blended',
#  u'blended cushions',
#  u'blended linen',
#  u'blends',
#  u'blends living',
#  u'blends style',
#  u'block',
#  u'block feet',
#  u'block legs',
#  u'block style',
#  u'block wood',
#  u'block yes',
#  u'blocked',
#  u'blocked durability',
#  u'blocked stapled',
#  u'blocking',
#  u'blocking guard',
#  u'blocks',
#  u'blocks reinforce',
#  u'blocks secure',
#  u'blocks staples',
#  u'blown',
#  u'blown fiber',
#  u'blown polyurethane',
#  u'blue',
#  u'blue chocolate',
#  u'blue gray',
#  u'boasts',
#  u'body',
#  u'body fabric',
#  u'body maximum',
#  u'bold',
#  u'bolster',
#  u'bolster pillows',
#  u'bolsters',
#  u'bonded',
#  u'bonded leather',
#  u'book',
#  u'boost',
#  u'boost comfort',
#  u'bordered',
#  u'bordered welted',
#  u'box',
#  u'box built',
#  u'box cushions',
#  u'box seat',
#  u'box seats',
#  u'box strength',
#  u'boxed',
#  u'boxed edge',
#  u'boxed seat',
#  u'bradstreet',
#  u'brand',
#  u'brand synonymous',
#  u'brass',
#  u'break',
#  u'break recycle',
#  u'breeze',
#  u'breeze just',
#  u'brewster',
#  u'bright',
#  u'brighton',
#  u'brighton collection',
#  u'bring',
#  u'bring collection',
#  u'brings',
#  u'broad',
#  u'brown',
#  u'brown accessorized',
#  u'brown block',
#  u'brown color',
#  u'brown wood',
#  u'brunch',
#  u'brunch entering',
#  u'brush',
#  u'brush lightly',
#  u'built',
#  u'built house',
#  u'built mere',
#  u'bun',
#  u'bun feet',
#  u'burnished',
#  u'burnished gold',
#  u'bushings',
#  u'bushings reduce',
#  u'bustle',
#  u'buttercup',
#  u'buttercup twill',
#  u'button',
#  u'button tufted',
#  u'button tufting',
#  u'buttons',
#  u'buttons plush',
#  u'ca',
#  u'ca117',
#  u'ca117 retardant',
#  u'cabriole',
#  u'california',
#  u'california cause',
#  u'california proposition',
#  u'camden',
#  u'camelback',
#  u'cams',
#  u'cams promote',
#  u'cancer',
#  u'cancer birth',
#  u'capacity',
#  u'capacity 600',
#  u'capacity assembly',
#  u'capacity hardware',
#  u'capacity hold',
#  u'capacity number',
#  u'capacity product',
#  u'capacity size',
#  u'cappuccino',
#  u'cappuccino finish',
#  u'carb',
#  u'carb compliant',
#  u'carbon',
#  u'carbon steel',
#  u'care',
#  u'care clean',
#  u'care wipe',
#  u'carefully',
#  u'carefully selected',
#  u'carmel',
#  u'carolina',
#  u'carolina dreamquest',
#  u'carolina filler',
#  u'carolina respected',
#  u'carolina usa',
#  u'caroline',
#  u'casey',
#  u'cast',
#  u'castor',
#  u'castor beans',
#  u'casual',
#  u'casual design',
#  u'casual lifestyle',
#  u'casual living',
#  u'casual skirted',
#  u'casual style',
#  u'catching',
#  u'catching appeal',
#  u'cause',
#  u'cause cancer',
#  u'center',
#  u'center room',
#  u'centerpiece',
#  u'century',
#  u'century design',
#  u'century modern',
#  u'certi',
#  u'certi pur',
#  u'certified',
#  u'chair',
#  u'chair create',
#  u'chairs',
#  u'chairs create',
#  u'chairs form',
#  u'chairs similar',
#  u'chaise',
#  u'charcoal',
#  u'charcoal blended',
#  u'charles',
#  u'charles london',
#  u'charm',
#  u'chemicals',
#  u'chemicals known',
#  u'chenille',
#  u'chenille assembly',
#  u'chenille fabric',
#  u'chenille pieces',
#  u'chenille product',
#  u'chenille seating',
#  u'chenille upholstery',
#  u'chesterfield',
#  u'chic',
#  u'chic comfort',
#  u'chic look',
#  u'china',
#  u'chocolate',
#  u'chocolate upholstery',
#  u'choice',
#  u'choice awaken',
#  u'choose',
#  u'choose best',
#  u'choose perfect',
#  u'choose sofa',
#  u'chrome',
#  u'chrome finish',
#  u'clack',
#  u'clack mechanism',
#  u'clack technology',
#  u'claire',
#  u'clark',
#  u'clarkedale',
#  u'class',
#  u'classic',
#  u'classic chesterfield',
#  u'classic contemporary',
#  u'classic nailhead',
#  u'classic rolled',
#  u'classic sofa',
#  u'classic style',
#  u'classic versatile',
#  u'classy',
#  u'classy sofa',
#  u'clean',
#  u'clean 100',
#  u'clean country',
#  u'clean damp',
#  u'clean dry',
#  u'clean durable',
#  u'clean good',
#  u'clean lined',
#  u'clean lines',
#  u'clean mild',
#  u'clean simple',
#  u'clean soft',
#  u'clean upholstery',
#  u'clean using',
#  u'clean water',
#  u'cleaned',
#  u'cleaned occasional',
#  u'cleaned product',
#  u'cleaner',
#  u'cleaner usa',
#  u'cleaner warranty',
#  u'cleaners',
#  u'cleaning',
#  u'cleaning product',
#  u'cleaning products',
#  u'cleaning recommended',
#  u'cleaning sofa',
#  u'cleaning solvent',
#  u'clearance',
#  u'clearance floor',
#  u'click',
#  u'click clack',
#  u'click slide',
#  u'click style',
#  u'close',
#  u'close functionality',
#  u'cloth',
#  u'cloth away',
#  u'cloth dipped',
#  u'cloth features',
#  u'cloth use',
#  u'club',
#  u'cocoa',
#  u'coffee',
#  u'coffee brunch',
#  u'coffee microsuede',
#  u'coil',
#  u'coil cushions',
#  u'coil gauge',
#  u'coil seating',
#  u'coil spring',
#  u'coils',
#  u'coils core',
#  u'coils individual',
#  u'coils smooth',
#  u'coils wrapped',
#  u'cold',
#  u'collection',
#  u'collection 100',
#  u'collection assembled',
#  u'collection color',
#  u'collection contemporary',
#  u'collection corner',
#  u'collection cushions',
#  u'collection design',
#  u'collection drawing',
#  u'collection features',
#  u'collection frame',
#  u'collection hardwood',
#  u'collection love',
#  u'collection manufactured',
#  u'collection material',
#  u'collection meterial',
#  u'collection pattern',
#  u'collection piece',
#  u'collection plush',
#  u'collection product',
#  u'collection quality',
#  u'collection seat',
#  u'collection sofa',
#  u'collection updated',
#  u'collection upholstered',
#  u'collection upholstery',
#  u'collection usa',
#  u'collection used',
#  u'collection wood',
#  u'collection wooden',
#  u'collection year',
#  u'color',
#  u'color beige',
#  u'color black',
#  u'color brown',
#  u'color dark',
#  u'color light',
#  u'color looks',
#  u'color options',
#  u'color rubber',
#  u'color schemes',
#  u'color silver',
#  u'color sofa',
#  u'color white',
#  u'colored',
#  u'colorful',
#  u'colors',
#  u'colors choose',
#  u'colors helping',
#  u'colors lets',
#  u'colors letting',
#  u'com',
#  u'combination',
#  u'combine',
#  u'combined',
#  u'combined plump',
#  u'combines',
#  u'come',
#  u'come features',
#  u'come plastic',
#  u'come upholstered',
#  u'comes',
#  u'comes assembled',
#  u'comes throw',
#  u'comfort',
#  u'comfort 100',
#  u'comfort 576',
#  u'comfort convertible',
#  u'comfort converts',
#  u'comfort cut',
#  u'comfort desire',
#  u'comfort durability',
#  u'comfort durable',
#  u'comfort easy',
#  u'comfort fashion',
#  u'comfort features',
#  u'comfort hallmarks',
#  u'comfort innersoft',
#  u'comfort letting',
#  u'comfort level',
#  u'comfort long',
#  u'comfort mind',
#  u'comfort perfect',
#  u'comfort plush',
#  u'comfort polyester',
#  u'comfort product',
#  u'comfort products',
#  u'comfort protection',
#  u'comfort rest',
#  u'comfort seating',
#  u'comfort sinuous',
#  u'comfort sitting',
#  u'comfort steel',
#  u'comfort style',
#  u'comfort support',
#  u'comfort tapered',
#  u'comfort usa',
#  u'comfort users',
#  u'comfortable',
#  u'comfortable durable',
#  u'comfortable fact',
#  u'comfortable highly',
#  u'comfortable lounger',
#  u'comfortable plush',
#  u'comfortable relaxed',
#  u'comfortable seat',
#  u'comfortable seating',
#  u'comfortable sit',
#  u'comfortable sleeper',
#  u'comfortable sofa',
#  u'comfortable stylish',
#  u'comfortable supportive',
#  u'comfortably',
#  u'comfy',
#  u'commercial',
#  u'commercial cleaning',
#  u'commercial residential',
#  u'committed',
#  u'committed manufacturing',
#  u'compact',
#  u'compartment',
#  u'compartments',
#  u'compartments prevent',
#  u'competitor',
#  u'complement',
#  u'complement decor',
#  u'complementing',
#  u'complements',
#  u'complements home',
#  u'complements variety',
#  u'complete',
#  u'complete look',
#  u'complete sofa',
#  u'completely',
#  u'compliant',
#  u'compliant ensure',
#  u'compliment',
#  u'compliment fit',
#  u'compliment smaller',
#  u'components',
#  u'components construction',
#  u'components product',
#  u'components sewn',
#  u'components year',
#  u'comprehensive',
#  u'comprehensive cuts',
#  u'compression',
#  u'compression foam',
#  u'cone',
#  u'cone shaped',
#  u'conforming',
#  u'conforming body',
#  u'connections',
#  u'connections strength',
#  u'consists',
#  u'consists hardwood',
#  u'constructed',
#  u'constructed hardwood',
#  u'constructed low',
#  u'constructed reinforced',
#  u'constructed solid',
#  u'constructed wood',
#  u'construction',
#  u'construction cappuccino',
#  u'construction delivery',
#  u'construction exclusively',
#  u'construction floor',
#  u'construction practically',
#  u'construction solid',
#  u'construction spot',
#  u'construction wrapped',
#  u'construction yes',
#  u'constructions',
#  u'constructions rigorously',
#  u'consumer',
#  u'contained',
#  u'contained non',
#  u'contains',
#  u'contains chemicals',
#  u'contemporary',
#  u'contemporary attached',
#  u'contemporary design',
#  u'contemporary designed',
#  u'contemporary flair',
#  u'contemporary frame',
#  u'contemporary home',
#  u'contemporary living',
#  u'contemporary look',
#  u'contemporary loveseat',
#  u'contemporary serves',
#  u'contemporary silhouette',
#  u'contemporary sofa',
#  u'contemporary space',
#  u'contemporary style',
#  u'contemporary styling',
#  u'contemporary update',
#  u'contemporary upholstered',
#  u'content',
#  u'continues',
#  u'continues today',
#  u'contour',
#  u'contour body',
#  u'contrast',
#  u'contrast stitching',
#  u'contrasting',
#  u'convenience',
#  u'convenient',
#  u'conveniently',
#  u'conversion',
#  u'convert',
#  u'convert couch',
#  u'converted',
#  u'converted bed',
#  u'convertible',
#  u'convertible frame',
#  u'convertible sectional',
#  u'convertible sleeper',
#  u'convertible sofa',
#  u'convertible upholstery',
#  u'convertibles',
#  u'convertibles collection',
#  u'converts',
#  u'converts bed',
#  u'converts quickly',
#  u'converts size',
#  u'converts sleeper',
#  u'converts sofa',
#  u'convey',
#  u'convey perfect',
#  u'cooper',
#  u'cooper sofa',
#  u'coordinated',
#  u'coordinated look',
#  u'coordinates',
#  u'coordinating',
#  u'coordinating arm',
#  u'coordinating pillows',
#  u'copenhagen',
#  u'copenhagen deluxe',
#  u'copenhagen sofa',
#  u'copper',
#  u'copper nail',
#  u'core',
#  u'core contained',
#  u'core layers',
#  u'cores',
#  u'cores constructed',
#  u'corner',
#  u'corner block',
#  u'corner blocked',
#  u'corner blocking',
#  u'corner blocks',
#  u'corner room',
#  u'corners',
#  u'corners glued',
#  u'corners stress',
#  u'corrosion',
#  u'corrosion resistant',
#  u'corrugated',
#  u'corrugated reinforced',
#  u'cotton',
#  u'cotton assembly',
#  u'cotton leather',
#  u'cotton linen',
#  u'cotton pieces',
#  u'cotton seating',
#  u'couch',
#  u'couch pillows',
#  u'couch product',
#  u'country',
#  u'country manufacture',
#  u'cover',
#  u'cover durable',
#  u'cover features',
#  u'cover help',
#  u'covered',
#  u'covered bonded',
#  u'covered durable',
#  u'covered high',
#  u'covered soft',
#  u'covering',
#  u'covers',
#  u'covers removable',
#  u'cowhide',
#  u'cozy',
#  u'crafted',
#  u'crafted north',
#  u'crafted right',
#  u'craftsmanship',
#  u'cream',
#  u'cream colored',
#  u'cream twill',
#  u'create',
#  u'create contemporary',
#  u'create coordinated',
#  u'create inviting',
#  u'create set',
#  u'create welcoming',
#  u'create wholesome',
#  u'creates',
#  u'creating',
#  u'creating illusion',
#  u'creating shining',
#  u'crisp',
#  u'crisp look',
#  u'crisp welt',
#  u'cross',
#  u'cross wires',
#  u'cruz',
#  u'cruz collection',
#  u'crystal',
#  u'crystal like',
#  u'cullen',
#  u'cullen collection',
#  u'cup',
#  u'cup holder',
#  u'currant',
#  u'currant twill',
#  u'curved',
#  u'curved arms',
#  u'curves',
#  u'curving',
#  u'curving track',
#  u'cushion',
#  u'cushion accommodates',
#  u'cushion adds',
#  u'cushion attached',
#  u'cushion bar',
#  u'cushion ca117',
#  u'cushion cores',
#  u'cushion covers',
#  u'cushion cushion',
#  u'cushion depth',
#  u'cushion design',
#  u'cushion encased',
#  u'cushion extra',
#  u'cushion forms',
#  u'cushion fully',
#  u'cushion height',
#  u'cushion product',
#  u'cushion protection',
#  u'cushion removable',
#  u'cushion rolled',
#  u'cushion seat',
#  u'cushion seating',
#  u'cushion thickness',
#  u'cushion upholstery',
#  u'cushion width',
#  u'cushion yes',
#  u'cushioned',
#  u'cushioning',
#  u'cushioning ca117',
#  u'cushioning seat',
#  u'cushions',
#  u'cushions armrests',
#  u'cushions artisan',
#  u'cushions attached',
#  u'cushions beautifully',
#  u'cushions button',
#  u'cushions comfortable',
#  u'cushions components',
#  u'cushions covered',
#  u'cushions create',
#  u'cushions cushion',
#  u'cushions cushions',
#  u'cushions decorative',
#  u'cushions elegant',
#  u'cushions encased',
#  u'cushions ensure',
#  u'cushions exclusively',
#  u'cushions fabric',
#  u'cushions fabricated',
#  u'cushions fabricates',
#  u'cushions faux',
#  u'cushions feature',
#  u'cushions features',
#  u'cushions filled',
#  u'cushions flared',
#  u'cushions flipped',
#  u'cushions graceful',
#  u'cushions heavy',
#  u'cushions high',
#  u'cushions highly',
#  u'cushions include',
#  u'cushions incredibly',
#  u'cushions integrated',
#  u'cushions looking',
#  ...]

# %%
def my_tokenizer(doc):
    '''
    INPUT: string
    OUTPUT: list of strings

    Tokenize and stem/lemmatize the document.
    '''   
    
    token = re.findall(r'\w+', doc.lower())
    
    sw = set(stopwords.words('english'))
    token_stop = [word for word in token if word not in sw]
    
    snowball = SnowballStemmer('english')
    sbs_ar = [snowball.stem(word) for word in token_stop]
    return sbs_ar

# %%
tfidf2 = TfidfVectorizer(tokenizer=my_tokenizer, max_features=1000, max_df=0.8, ngram_range = (1,2))
tfidf_matrix2 = tfidf2.fit_transform(X).todense()
tfidf2.get_feature_names()
# Out:
# [u'1',
#  u'1 8',
#  u'1 year',
#  u'100',
#  u'100 polyest',
#  u'2',
#  u'2 assembl',
#  u'2 throw',
#  u'3',
#  u'3 assembl',
#  u'34',
#  u'34 lbs',
#  u'4',
#  u'4 5',
#  u'5',
#  u'5 cushion',
#  u'5 inch',
#  u'6',
#  u'7',
#  u'7 8',
#  u'8',
#  u'8 gaug',
#  u'8 hardwood',
#  u'8 lbs',
#  u'8 oz',
#  u'accent',
#  u'accent chair',
#  u'accent pillow',
#  u'accessor',
#  u'accessor match',
#  u'ad',
#  u'add',
#  u'addit',
#  u'addit comfort',
#  u'addit live',
#  u'adjust',
#  u'adjust headrest',
#  u'adorn',
#  u'afford',
#  u'afford solut',
#  u'ahfa',
#  u'ahfa standard',
#  u'aid',
#  u'aid design',
#  u'air',
#  u'air blown',
#  u'allow',
#  u'along',
#  u'also',
#  u'also use',
#  u'anchor',
#  u'anchor good',
#  u'anti',
#  u'anti sag',
#  u'appeal',
#  u'applic',
#  u'applic residenti',
#  u'approv',
#  u'approv wearabl',
#  u'area',
#  u'area frame',
#  u'arm',
#  u'arm arm',
#  u'arm design',
#  u'arm upholsteri',
#  u'armrest',
#  u'artisan',
#  u'artisan craft',
#  u'assembl',
#  u'assembl requir',
#  u'assembl unit',
#  u'attach',
#  u'attach back',
#  u'attract',
#  u'avail',
#  u'avail multipl',
#  u'back',
#  u'back arm',
#  u'back cushion',
#  u'back pillow',
#  u'back seat',
#  u'back spring',
#  u'bailey',
#  u'balanc',
#  u'base',
#  u'bean',
#  u'bear',
#  u'bear area',
#  u'beauti',
#  u'bed',
#  u'beig',
#  u'best',
#  u'best style',
#  u'black',
#  u'blend',
#  u'blend cushion',
#  u'blend linen',
#  u'blend upholsteri',
#  u'block',
#  u'block feet',
#  u'block leg',
#  u'block stapl',
#  u'blown',
#  u'blown polyurethan',
#  u'blue',
#  u'bodi',
#  u'bodi maximum',
#  u'bond',
#  u'bond leather',
#  u'bottom',
#  u'box',
#  u'bring',
#  u'bring collect',
#  u'brown',
#  u'built',
#  u'bush',
#  u'bush reduc',
#  u'button',
#  u'button tuft',
#  u'california',
#  u'cam',
#  u'cam promot',
#  u'capac',
#  u'capac 2',
#  u'capac 3',
#  u'care',
#  u'carolina',
#  u'carolina respect',
#  u'castor',
#  u'casual',
#  u'centuri',
#  u'certi',
#  u'certi pur',
#  u'chair',
#  u'chair creat',
#  u'chais',
#  u'chenill',
#  u'chic',
#  u'china',
#  u'choos',
#  u'classic',
#  u'classic roll',
#  u'clean',
#  u'clean line',
#  u'clean product',
#  u'clean water',
#  u'cleaner',
#  u'click',
#  u'cloth',
#  u'coil',
#  u'coil spring',
#  u'collect',
#  u'collect assembl',
#  u'collect featur',
#  u'collect made',
#  u'collect materi',
#  u'collect qualiti',
#  u'collect wood',
#  u'color',
#  u'combin',
#  u'come',
#  u'comfort',
#  u'comfort cut',
#  u'comfort durabl',
#  u'comfort featur',
#  u'comfort seat',
#  u'comfort style',
#  u'comfort support',
#  u'commerci',
#  u'commerci residenti',
#  u'commit',
#  u'commit manufactur',
#  u'compart',
#  u'complement',
#  u'complet',
#  u'compliment',
#  u'compliment fit',
#  u'compliment smaller',
#  u'compon',
#  u'compon product',
#  u'compress',
#  u'compress foam',
#  u'consist',
#  u'construct',
#  u'construct hardwood',
#  u'construct low',
#  u'construct rigor',
#  u'construct wrap',
#  u'contain',
#  u'contemporari',
#  u'contemporari design',
#  u'contemporari frame',
#  u'contemporari style',
#  u'contour',
#  u'contour bodi',
#  u'contrast',
#  u'conveni',
#  u'convert',
#  u'convert frame',
#  u'convert sofa',
#  u'convert upholsteri',
#  u'coordin',
#  u'coordin look',
#  u'cor',
#  u'core',
#  u'core construct',
#  u'corner',
#  u'corner block',
#  u'corner glu',
#  u'corner stress',
#  u'cotton',
#  u'couch',
#  u'countri',
#  u'countri manufactur',
#  u'cover',
#  u'cozi',
#  u'craft',
#  u'craft north',
#  u'craft right',
#  u'cream',
#  u'creat',
#  u'creat coordin',
#  u'crisp',
#  u'crisp welt',
#  u'curv',
#  u'cushion',
#  u'cushion 1',
#  u'cushion attach',
#  u'cushion back',
#  u'cushion compon',
#  u'cushion core',
#  u'cushion cover',
#  u'cushion fabric',
#  u'cushion featur',
#  u'cushion high',
#  u'cushion offer',
#  u'cushion pillowtop',
#  u'cushion remov',
#  u'cushion revers',
#  u'cushion seat',
#  u'cushion thick',
#  u'cushion yes',
#  u'custom',
#  u'custom upholsteri',
#  u'cut',
#  u'cut 7',
#  u'cut grade',
#  u'd',
#  u'd cor',
#  u'dacron',
#  u'dark',
#  u'dark espresso',
#  u'day',
#  u'decor',
#  u'densiti',
#  u'densiti 34',
#  u'densiti foam',
#  u'densiti plastic',
#  u'depth',
#  u'depth front',
#  u'deriv',
#  u'design convert',
#  u'design give',
#  u'design reclin',
#  u'design sleeper',
#  u'design standard',
#  u'detail frame',
#  u'detail product',
#  u'dorm',
#  u'dorm guest',
#  u'doubl',
#  u'doubl row',
#  u'dri',
#  u'dri clean',
#  u'dri hardwood',
#  u'durabl',
#  u'durabl ahfa',
#  u'durabl corner',
#  u'durabl fabric',
#  u'durabl individu',
#  u'durabl last',
#  u'durabl upholst',
#  u'durablend',
#  u'dust',
#  u'dust spot',
#  u'duti',
#  u'duti 8',
#  u'easi',
#  u'easi clean',
#  u'easili',
#  u'easili clean',
#  u'easili convert',
#  u'eco',
#  u'eco friend',
#  u'edg',
#  u'eleg',
#  u'encas',
#  u'end',
#  u'engin',
#  u'enhanc',
#  u'enjoy',
#  u'ensur',
#  u'ensur comfort',
#  u'ensur last',
#  u'environ',
#  u'environ improv',
#  u'environment',
#  u'environment footprint',
#  u'environment friend',
#  u'espresso',
#  u'espresso finish',
#  u'exclus',
#  u'exclus product',
#  u'extra',
#  u'extra room',
#  u'fabric',
#  u'fabric 1',
#  u'fabric bailey',
#  u'fabric griffin',
#  u'fabric hand',
#  u'fabric jackson',
#  u'fabric pre',
#  u'fabric upholsteri',
#  u'fashion',
#  u'faux',
#  u'faux leather',
#  u'featur contemporari',
#  u'featur hardwood',
#  u'featur includ',
#  u'featur materi',
#  u'featur reinforc',
#  u'featur stress',
#  u'featur wood',
#  u'feel',
#  u'feet',
#  u'fiber',
#  u'fiber contour',
#  u'fiber wrap',
#  u'fill',
#  u'find',
#  u'finish',
#  u'firm',
#  u'fit',
#  u'fit today',
#  u'flare',
#  u'flare arm',
#  u'floor',
#  u'foam',
#  u'foam cushion',
#  u'foam durabl',
#  u'foam fabric',
#  u'foam fill',
#  u'foam made',
#  u'foam polyest',
#  u'foam wrap',
#  u'fold',
#  u'footprint',
#  u'footprint featur',
#  u'form',
#  u'formaldehyd',
#  u'formaldehyd free',
#  u'foundat',
#  u'foundat reclin',
#  u'four',
#  u'frame',
#  u'frame certi',
#  u'frame construct',
#  u'frame finish',
#  u'frame high',
#  u'frame materi',
#  u'frame piec',
#  u'frame provid',
#  u'frame spring',
#  u'free',
#  u'free made',
#  u'free solvent',
#  u'frequent',
#  u'frequent remov',
#  u'friend',
#  u'front',
#  u'front back',
#  u'full',
#  u'full size',
#  u'fulli',
#  u'fulli reclin',
#  u'function',
#  u'furnitur',
#  u'furnitur manufactur',
#  u'gaug',
#  u'gaug anti',
#  u'generous',
#  u'give',
#  u'give best',
#  u'global',
#  u'global compon',
#  u'glu',
#  u'glu block',
#  u'glue',
#  u'glue block',
#  u'go',
#  u'goe',
#  u'good',
#  u'good seat',
#  u'grace',
#  u'grade',
#  u'grade lumber',
#  u'grain',
#  u'gray',
#  u'great',
#  u'great piec',
#  u'griffin',
#  u'guest',
#  u'guest room',
#  u'hand',
#  u'hand insur',
#  u'hand tailor',
#  u'handi',
#  u'hardwood',
#  u'hardwood frame',
#  u'hardwood lumber',
#  u'hardwood materi',
#  u'hassl',
#  u'head',
#  u'head trim',
#  u'headrest',
#  u'headrest seat',
#  u'heavi',
#  u'heavi duti',
#  u'height',
#  u'height top',
#  u'help',
#  u'help maintain',
#  u'high',
#  u'high densiti',
#  u'high qualiti',
#  u'high resili',
#  u'home',
#  u'home decor',
#  u'home transport',
#  u'ideal',
#  u'improv',
#  u'improv durabl',
#  u'inch',
#  u'inch back',
#  u'inch leg',
#  u'inch seat',
#  u'includ',
#  u'includ 1',
#  u'includ 2',
#  u'includ sofa',
#  u'includ two',
#  u'independ',
#  u'individu',
#  u'individu frame',
#  u'industri',
#  u'innerspr',
#  u'innov',
#  u'inspir',
#  u'insur',
#  u'insur qualiti',
#  u'invit',
#  u'item',
#  u'item includ',
#  u'jackson',
#  u'join',
#  u'join doubl',
#  u'joint',
#  u'keep',
#  u'kiln',
#  u'kiln dri',
#  u'knife',
#  u'knife edg',
#  u'labor',
#  u'lamin',
#  u'lamin frame',
#  u'last',
#  u'last comfort',
#  u'last qualiti',
#  u'last support',
#  u'layer',
#  u'lbs',
#  u'lbs compress',
#  u'lbs densiti',
#  u'leather',
#  u'leather seat',
#  u'leather sofa',
#  u'leather upholsteri',
#  u'leg',
#  u'leg attach',
#  u'leg yes',
#  u'leggett',
#  u'leggett platt',
#  u'lend',
#  u'let',
#  u'lifetim',
#  u'lifetim warranti',
#  u'like',
#  u'limit',
#  u'limit warranti',
#  u'line',
#  u'linen',
#  u'linen fabric',
#  u'linen upholsteri',
#  u'live',
#  u'live room',
#  u'live space',
#  u'liven',
#  u'liven room',
#  u'load',
#  u'load bear',
#  u'long',
#  u'long last',
#  u'look',
#  u'look featur',
#  u'loop',
#  u'loop sinuous',
#  u'loos',
#  u'loos back',
#  u'loung',
#  u'love',
#  u'love seat',
#  u'loveseat',
#  u'low',
#  u'low melt',
#  u'lumber',
#  u'lumber hand',
#  u'lumber stress',
#  u'luxuri',
#  u'machin',
#  u'machin test',
#  u'made',
#  u'made usa',
#  u'mahogani',
#  u'maintain',
#  u'make',
#  u'mani',
#  u'manufactur',
#  u'manufactur 1',
#  u'manufactur bring',
#  u'manufactur china',
#  u'manufactur process',
#  u'manufactur qualiti',
#  u'manufactur unit',
#  u'manufactur wood',
#  u'massag',
#  u'massag adjust',
#  u'match',
#  u'match accent',
#  u'materi 100',
#  u'materi assembl',
#  u'materi chenill',
#  u'materi cotton',
#  u'materi faux',
#  u'materi leather',
#  u'materi linen',
#  u'materi manufactur',
#  u'materi microfib',
#  u'materi piec',
#  u'materi possibl',
#  u'materi seat',
#  u'materi wood',
#  u'mattress',
#  u'maximum',
#  u'maximum support',
#  u'mechan',
#  u'mechan nylon',
#  u'medium',
#  u'melt',
#  u'melt fiber',
#  u'metal',
#  u'metal manufactur',
#  u'microfib',
#  u'microfib assembl',
#  u'microfib seat',
#  u'microfib upholsteri',
#  u'microsued',
#  u'microsued fabric',
#  u'mid',
#  u'mid centuri',
#  u'mild',
#  u'mind',
#  u'mind use',
#  u'minim',
#  u'minim environment',
#  u'minimum',
#  u'minimum 4',
#  u'minut',
#  u'modern',
#  u'much',
#  u'multipl',
#  u'multipl color',
#  u'multipl cushion',
#  u'nail',
#  u'nail head',
#  u'nailhead',
#  u'nailhead trim',
#  u'need',
#  u'nois',
#  u'non',
#  u'non woven',
#  u'north',
#  u'north carolina',
#  u'number',
#  u'number item',
#  u'nylon',
#  u'nylon bush',
#  u'occasion',
#  u'offer',
#  u'omega',
#  u'omega rocker',
#  u'one',
#  u'one north',
#  u'open',
#  u'oper',
#  u'oper durabl',
#  u'option',
#  u'ottoman',
#  u'oz',
#  u'oz dacron',
#  u'pad',
#  u'pad arm',
#  u'pair',
#  u'part',
#  u'pattern',
#  u'peopl',
#  u'per',
#  u'perfect',
#  u'piec',
#  u'piec dorm',
#  u'piec furnitur',
#  u'piec includ',
#  u'piec reinforc',
#  u'pillow',
#  u'pillow air',
#  u'pillow featur',
#  u'pillow includ',
#  u'pillow product',
#  u'pillow seat',
#  u'pillow top',
#  u'pillowtop',
#  u'place',
#  u'plastic',
#  u'plastic leg',
#  u'plastic rocker',
#  u'platt',
#  u'platt omega',
#  u'plush',
#  u'plywood',
#  u'pocket',
#  u'pocket coil',
#  u'point',
#  u'point glue',
#  u'point load',
#  u'poli',
#  u'polyest',
#  u'polyest fabric',
#  u'polyest fiber',
#  u'polyest upholsteri',
#  u'polyol',
#  u'polyurethan',
#  u'polyurethan foam',
#  u'posit',
#  u'possibl',
#  u'possibl aid',
#  u'pre',
#  u'pre approv',
#  u'premium',
#  u'print',
#  u'print solid',
#  u'process',
#  u'product care',
#  u'product manufactur',
#  u'product type',
#  u'product warranti',
#  u'promot',
#  u'promot comfort',
#  u'promot smooth',
#  u'protect',
#  u'provid',
#  u'provid anchor',
#  u'provid last',
#  u'pull',
#  u'pur',
#  u'pur foam',
#  u'qualiti',
#  u'qualiti custom',
#  u'qualiti foam',
#  u'qualiti foundat',
#  u'qualiti mind',
#  u'qualiti step',
#  u'queen',
#  u'queen size',
#  u'quick',
#  u'rail',
#  u'rail cut',
#  u'reclin',
#  u'reclin spring',
#  u'reclin storag',
#  u'reclin upholsteri',
#  u'recommend',
#  u'recycl',
#  u'recycl materi',
#  u'reduc',
#  u'reduc nois',
#  u'refin',
#  u'reinforc',
#  u'reinforc corner',
#  u'reinforc hardwood',
#  u'relax',
#  u'remov',
#  u'remov cushion',
#  u'remov dust',
#  u'remov seat',
#  u'requir',
#  u'requir assembl',
#  u'requir product',
#  u'requir yes',
#  u'residenti',
#  u'residenti leg',
#  u'resili',
#  u'respect',
#  u'respect furnitur',
#  u'rest',
#  u'retard',
#  u'revers',
#  u'revers seat',
#  u'rich',
#  u'right',
#  u'right usa',
#  u'rigor',
#  u'rigor test',
#  u'rocker',
#  u'rocker cam',
#  u'rocker stationari',
#  u'roll',
#  u'roll arm',
#  u'room',
#  u'room extra',
#  u'room vacat',
#  u'round',
#  u'round arm',
#  u'row',
#  u'row tie',
#  u'sag',
#  u'sag sinuous',
#  u'seam',
#  u'seat',
#  u'seat applic',
#  u'seat area',
#  u'seat back',
#  u'seat capac',
#  u'seat comfort',
#  u'seat cushion',
#  u'seat provid',
#  u'seat style',
#  u'seat support',
#  u'seat yes',
#  u'section',
#  u'secur',
#  u'secur join',
#  u'serta',
#  u'serv',
#  u'serv great',
#  u'set',
#  u'sette',
#  u'sewn',
#  u'shape',
#  u'side',
#  u'side side',
#  u'signatur',
#  u'silhouett',
#  u'simmon',
#  u'simpl',
#  u'simul',
#  u'simul home',
#  u'sinuous',
#  u'sinuous spring',
#  u'sinuous wire',
#  u'sit',
#  u'size',
#  u'size bed',
#  u'skirt',
#  u'sleek',
#  u'sleep',
#  u'sleeper',
#  u'sleeper frame',
#  u'sleeper sofa',
#  u'sleeper upholsteri',
#  u'slipcov',
#  u'smaller',
#  u'smaller space',
#  u'smooth',
#  u'smooth oper',
#  u'sofa',
#  u'sofa 2',
#  u'sofa bed',
#  u'sofa convert',
#  u'sofa featur',
#  u'sofa made',
#  u'sofa offer',
#  u'sofa perfect',
#  u'sofa sleeper',
#  u'sofa style',
#  u'sofab',
#  u'soft',
#  u'solid',
#  u'solid massag',
#  u'solid welt',
#  u'solid wood',
#  u'solut',
#  u'solut use',
#  u'solvent',
#  u'solvent dri',
#  u'sophist',
#  u'space',
#  u'space liven',
#  u'space toss',
#  u'split',
#  u'sport',
#  u'spot',
#  u'spot clean',
#  u'spring',
#  u'spring machin',
#  u'spring rail',
#  u'spring seat',
#  u'spring secur',
#  u'spring system',
#  u'squar',
#  u'stand',
#  u'standard',
#  u'standard cushion',
#  u'standard frame',
#  u'standard print',
#  u'standard upholsteri',
#  u'stapl',
#  u'stapl leggett',
#  u'state',
#  u'state global',
#  u'stationari',
#  u'stationari mechan',
#  u'steel',
#  u'steel seat',
#  u'step',
#  u'step manufactur',
#  u'stitch',
#  u'storag',
#  u'storag space',
#  u'strength',
#  u'strength durabl',
#  u'stress',
#  u'stress point',
#  u'stress welt',
#  u'strong',
#  u'structur',
#  u'sturdi',
#  u'sturdi frame',
#  u'style',
#  u'style contemporari',
#  u'style multipl',
#  u'style sofa',
#  u'stylish',
#  u'stylish afford',
#  u'superior',
#  u'support',
#  u'support comfort',
#  u'support commit',
#  u'support sturdi',
#  u'sure',
#  u'system',
#  u'tailor',
#  u'tailor piec',
#  u'take',
#  u'taper',
#  u'test',
#  u'test durabl',
#  u'test simul',
#  u'thick',
#  u'thick promot',
#  u'three',
#  u'throw',
#  u'throw pillow',
#  u'tie',
#  u'tie wire',
#  u'tight',
#  u'time',
#  u'timeless',
#  u'today',
#  u'today home',
#  u'togeth',
#  u'tone',
#  u'tool',
#  u'top',
#  u'top bottom',
#  u'top grain',
#  u'top seat',
#  u'toss',
#  u'toss pillow',
#  u'touch',
#  u'track',
#  u'track arm',
#  u'tradit',
#  u'tradit style',
#  u'transform',
#  u'transit',
#  u'transit style',
#  u'transport',
#  u'transport environ',
#  u'tri',
#  u'trim',
#  u'tuft',
#  u'tuft back',
#  u'turn',
#  u'twill',
#  u'twill fabric',
#  u'twin',
#  u'two',
#  u'type',
#  u'type sofa',
#  u'unit',
#  u'unit state',
#  u'updat',
#  u'upholst',
#  u'upholst sofa',
#  u'upholsteri color',
#  u'upholsteri craft',
#  u'upholsteri cushion',
#  u'upholsteri seat',
#  u'usa',
#  u'usa featur',
#  u'usa product',
#  u'use',
#  u'use compliment',
#  u'use hardwood',
#  u'use recycl',
#  u'vacat',
#  u'vacat home',
#  u'vacuum',
#  u'vacuum frequent',
#  u'valu',
#  u'valu minim',
#  u'various',
#  u'velvet',
#  u'versatil',
#  u'vinyl',
#  u'warranti',
#  u'warranti 1',
#  u'warranti cushion',
#  u'warranti frame',
#  u'warranti product',
#  u'water',
#  u'water base',
#  u'water free',
#  u'wearabl',
#  u'wearabl durabl',
#  u'weight',
#  u'well',
#  u'welt',
#  u'welt cushion',
#  u'welt detail',
#  u'welt ensur',
#  u'welt seat',
#  u'white',
#  u'wide',
#  u'width',
#  u'width side',
#  u'wildon',
#  u'wildon home',
#  u'wipe',
#  u'wipe clean',
#  u'wire',
#  u'wire spring',
#  u'without',
#  u'wood',
#  u'wood arm',
#  u'wood frame',
#  u'wood lamin',
#  u'wood leg',
#  u'wood manufactur',
#  u'wood metal',
#  u'wood upholsteri',
#  u'wooden',
#  u'wooden frame',
#  u'wooden leg',
#  u'work',
#  u'work one',
#  u'woven',
#  u'wrap',
#  u'wrap foam',
#  u'wrap high',
#  u'wrap pocket',
#  u'x',
#  u'year',
#  u'year come',
#  u'year limit',
#  u'year warranti',
#  u'yes',
#  u'yes back',
#  u'yes product',
#  u'yes seat',
#  u'yet']

# %% [markdown]
# # Then cluster with tfidf matrix

# %%
km_model = KMeans(n_clusters=10)
km_model.fit(tfidf_matrix)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
# max_features=5000
centroids = km_model.cluster_centers_
centroid_top_10_index = [np.argsort(centroids, axis=1)[i][::-1][0:10] for i in xrange(centroids.shape[0])]
feature_names = np.array(tfidf.get_feature_names())
for i in range(len(centroid_top_10_index)):
    print feature_names[centroid_top_10_index[i]]
# Out:
# [u'charcoal blended' u'artisan' u'contemporary living' u'casual living'
#  u'compartments' u'completely' u'cause cancer' u'cushions comfortable'
#  u'block' u'angle']
# [u'corner blocked' u'brown color' u'away' u'areas skillfully' u'burnished'
#  u'cushions button' u'cowhide' u'bold' u'blends' u'cushions flipped']
# [u'cushion adds' u'cleaners' u'blocking' u'bonded' u'blend upholstery'
#  u'brewster' u'blend' u'accessorized matching' u'country' u'chic look']
# [u'bags' u'book' u'coordinates' u'70 plywood' u'bonded leather'
#  u'comfort cut' u'70' u'clean lines' u'coordinated look' u'charles london']
# [u'cotton leather' u'collection year' u'cores constructed' u'charm'
#  u'cores' u'commercial residential' u'cleaning' u'combines' u'choose'
#  u'care clean']
# [u'cloth dipped' u'affordable solution' u'cloth away' u'arms spacious'
#  u'assembly breeze' u'assembly arrival' u'artisan' u'comfort converts'
#  u'currant twill' u'anti sag']
# [u'cushions comfortable' u'contemporary living' u'contained non'
#  u'cushion extra' u'block' u'components construction' u'angle'
#  u'cushions flared' u'carefully selected' u'700']
# [u'arms' u'arms artisan' u'contemporary living' u'accents' u'bedroom'
#  u'bed touch' u'carefully selected' u'audrina' u'arms blended'
#  u'arms block']
# [u'completely' u'cushions highly' u'buttercup' u'contemporary living'
#  u'arms waterfall' u'corners' u'arrival' u'contemporary update'
#  u'compliant ensure' u'comfortable plush']
# [u'beautifully adorned' u'amanda' u'bench' u'arm rest' u'accommodates size'
#  u'cushion protection' u'block feet' u'crisp' u'converted bed'
#  u'cushions feature']

# %%
# max_features=1000
centroids = km_model.cluster_centers_
centroid_top_10_index = [np.argsort(centroids, axis=1)[i][::-1][0:10] for i in xrange(centroids.shape[0])]
feature_names = np.array(tfidf.get_feature_names())
for i in range(len(centroid_top_10_index)):
    print feature_names[centroid_top_10_index[i]]
# Out:
# [u'loveseat' u'cushions' u'sofa' u'linen' u'room' u'seat' u'living' u'wood'
#  u'frame' u'collection']
# [u'structure' u'heavy' u'double' u'compliment' u'homes' u'wire' u'today'
#  u'gauge' u'forms' u'year limited']
# [u'using hardwood' u'mind using' u'frames certi' u'giving best'
#  u'footprint features' u'hand tailored' u'foam durable' u'best style'
#  u'tailored piece' u'manufactured quality']
# [u'durability' u'global components' u'states global' u'assembled united'
#  u'global' u'quality foam' u'assembled' u'melt fiber' u'states' u'low melt']
# [u'support' u'points' u'stress points' u'lumber' u'stress' u'rocker'
#  u'minimum' u'promote' u'manufacturing' u'lbs']
# [u'north carolina' u'carolina' u'north' u'crafted' u'custom upholstery'
#  u'custom' u'cushions' u'quality custom' u'usa features'
#  u'collection quality']
# [u'wood' u'sofa' u'sleeper' u'warranty' u'frame' u'seating' u'collection'
#  u'year' u'leather' u'assembly']
# [u'convertible' u'convertible sofa' u'sofa' u'bed' u'faux leather' u'faux'
#  u'leather' u'design convertible' u'convertible upholstery' u'converts']
# [u'seat' u'yes' u'inches' u'sofa' u'cushion' u'style' u'cushion yes'
#  u'solid' u'seat cushion' u'residential']
# [u'fabric' u'clean' u'features wood' u'construction wrapped' u'blended'
#  u'water' u'frame construction' u'twill' u'spot clean' u'wrapped foam']

# %%
centroids
# Out:
# array([[  1.50544846e-02,   1.33764255e-02,   2.46414645e-02, ...,
#          -9.54097912e-18,  -7.37257477e-18,  -7.37257477e-18],
#        [  3.17307205e-02,   1.94945381e-02,   1.53861298e-02, ...,
#          -8.67361738e-18,  -6.93889390e-18,  -6.93889390e-18],
#        [  2.28476434e-02,   1.45452839e-02,   7.54961971e-03, ...,
#           6.01043219e-02,   4.25920605e-02,   4.25920605e-02],
#        ...,
#        [  8.64934921e-03,  -5.20417043e-18,   1.61268172e-02, ...,
#           3.46944695e-18,   1.30104261e-18,   1.30104261e-18],
#        [  3.46944695e-18,   1.73472348e-18,   6.93889390e-18, ...,
#           0.00000000e+00,   4.33680869e-19,   4.33680869e-19],
#        [  1.15722053e-02,   9.07156046e-03,   3.44180069e-02, ...,
#           8.67361738e-19,   8.67361738e-19,   8.67361738e-19]])

# %%
text_clustering_result = collections.defaultdict(list)

for i, label in enumerate(km_model.labels_):
    text_clustering_result[label].append(int(X.index[i]))

# %%
for i in text_clustering_result:
    print i, text_clustering_result[i]
# Out:
# 0 [1, 10, 105, 116, 117, 12, 121, 122, 134, 137, 138, 140, 144, 145, 151, 152, 159, 160, 169, 176, 178, 18, 183, 184, 189, 195, 197, 199, 2, 20, 201, 204, 212, 219, 22, 220, 227, 228, 234, 243, 245, 246, 248, 249, 252, 258, 260, 266, 269, 272, 279, 283, 288, 291, 304, 305, 306, 307, 319, 321, 328, 33, 331, 332, 336, 340, 343, 344, 345, 347, 349, 353, 354, 356, 357, 361, 362, 368, 369, 37, 371, 379, 380, 381, 384, 387, 390, 393, 397, 4, 401, 408, 41, 415, 416, 418, 42, 420, 421, 424, 426, 430, 432, 433, 442, 446, 448, 449, 450, 453, 466, 468, 471, 478, 479, 48, 49, 52, 57, 6, 60, 64, 69, 7, 72, 78, 8, 91, 92, 93, 94, 95]
# 1 [102, 108, 111, 124, 129, 133, 136, 142, 147, 148, 158, 164, 165, 172, 173, 177, 181, 185, 186, 188, 191, 192, 196, 198, 200, 207, 213, 215, 218, 222, 225, 229, 240, 241, 244, 253, 254, 262, 263, 265, 277, 284, 286, 294, 296, 297, 300, 302, 303, 308, 310, 311, 314, 320, 323, 324, 325, 326, 327, 329, 335, 338, 352, 358, 359, 363, 364, 367, 372, 374, 376, 382, 383, 385, 386, 388, 389, 394, 395, 396, 398, 399, 402, 404, 405, 406, 407, 409, 411, 417, 422, 427, 428, 429, 431, 434, 438, 44, 440, 443, 445, 451, 452, 454, 458, 459, 460, 461, 463, 467, 469, 47, 472, 473, 474, 475]
# 2 [100, 126, 130, 132, 15, 157, 162, 193, 203, 211, 216, 217, 250, 255, 261, 281, 290, 292, 309, 317, 318, 334, 337, 348, 413, 423, 435, 436, 444, 46, 477, 54, 65, 74, 81]
# 3 [113, 120, 166, 168, 209, 210, 230, 232, 235, 239, 24, 259, 273, 275, 276, 280, 289, 293, 299, 3, 312, 322, 333, 34, 36, 365, 370, 412, 414, 425, 439, 441, 455, 456, 465, 90]
# 4 [0, 112, 127, 13, 131, 143, 149, 155, 163, 167, 174, 175, 187, 226, 237, 25, 256, 264, 278, 287, 313, 315, 316, 330, 342, 366, 375, 38, 400, 403, 419, 437, 447, 457, 464, 5, 50, 71]
# 5 [106, 150, 153, 154, 182, 205, 21, 236, 238, 242, 257, 26, 282, 31, 341, 35, 351, 410, 470, 67, 73, 9, 97]
# 6 [101, 118, 123, 141, 156, 16, 161, 17, 171, 19, 194, 214, 23, 27, 270, 32, 45, 63, 70, 75, 76, 79, 80, 84, 85, 88]
# 7 [103, 104, 107, 11, 110, 114, 119, 14, 180, 190, 208, 221, 224, 231, 233, 28, 29, 30, 301, 350, 355, 40, 43, 462, 51, 53, 55, 58, 59, 61, 62, 68, 77, 82, 83, 89, 98, 99]
# 8 [128, 146, 170, 179, 202, 206, 223, 267, 268, 274, 285, 295, 298, 378, 39, 86]
# 9 [109, 115, 125, 135, 139, 247, 251, 271, 339, 346, 360, 373, 377, 391, 392, 476, 56, 66, 87, 96]

# %%
sofa_df.ix[106].product_id
# Out:
# u'XSQ1448'

# %% [markdown]
# # Visualize text clustering result:

# %%
category = 'sofa'
paths = get_paths(category)

# %%
time.ctime(time.time())
# Out:
# 'Mon Sep 28 12:15:24 2015'

# %%
for i in text_clustering_result:
    for j in text_clustering_result[i]:
        product_id = sofa_df.ix[j].product_id
        for path in paths:
            if product_id in path:
                image = skimage.io.imread('wayfair/images/' + category + '/' + path)
                new_path = 'wayfair/images/' + category + '/text_clustering/' + str(i) + '/' + path
                skimage.io.imsave(new_path, image)

# %%
time.ctime(time.time())
# Out:
# 'Mon Sep 28 12:17:05 2015'

# %% [markdown]
# # Results: alright I guess?

# %% [markdown]
# # Clean all text data & save to new json

# %%
sofa_df = pd.read_json('wayfair/sofa.json')
sofa_bed_df = pd.read_json('wayfair/sofa_bed.json')
futon_df = pd.read_json('wayfair/futon.json')
loveseat_df = pd.read_json('wayfair/loveseat.json')
coffee_table_df = pd.read_json('wayfair/coffee_table.json')
desk_df = pd.read_json('wayfair/desk.json')
office_chair_df = pd.read_json('wayfair/office_chair.json')
bookcase_df = pd.read_json('wayfair/bookcase.json')
dining_table_df = pd.read_json('wayfair/dining_table.json')
dining_chair_df = pd.read_json('wayfair/dining_chair.json')
bed_df = pd.read_json('wayfair/bed.json')
nightstand_df = pd.read_json('wayfair/nightstand.json')
dresser_df = pd.read_json('wayfair/dresser.json')

# %%
sofa_df = clean_text_data(sofa_df, sofa=True)
sofa_bed_df = clean_text_data(sofa_bed_df, sofa=True)
futon_df = clean_text_data(futon_df, sofa=True)
loveseat_df = clean_text_data(loveseat_df, sofa=True)
coffee_table_df = clean_text_data(coffee_table_df)
desk_df = clean_text_data(desk_df)
office_chair_df = clean_text_data(office_chair_df)
bookcase_df = clean_text_data(bookcase_df)
dining_table_df = clean_text_data(dining_table_df)
dining_chair_df = clean_text_data(dining_chair_df)
bed_df = clean_text_data(bed_df)
nightstand_df = clean_text_data(nightstand_df)
dresser_df = clean_text_data(dresser_df)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dresser_df[dresser_df['description_all'] == '\n']
# Out:
# Empty DataFrame
# Columns: [category, colors, description, features, image_links_all, image_links_by_color, manufacturer, price, product_id, rating_avg, rating_count, specs, title, url, website, description_all]
# Index: []

# %%
sofa_all_df = sofa_df

# %% [markdown]
# # Remove replicates

# %%
for i in sofa_bed_df.index:
    if i not in sofa_all_df.index:
        product_df = pd.DataFrame(sofa_bed_df.ix[i]).T
        sofa_all_df = pd.concat([sofa_all_df, product_df], axis=0)
for i in futon_df.index:
    if i not in sofa_all_df.index:
        product_df = pd.DataFrame(futon_df.ix[i]).T
        sofa_all_df = pd.concat([sofa_all_df, product_df], axis=0)
for i in loveseat_df.index:
    if i not in sofa_all_df.index:
        product_df = pd.DataFrame(loveseat_df.ix[i]).T
        sofa_all_df = pd.concat([sofa_all_df, product_df], axis=0)

# %%
sofa_all_df = sofa_all_df.reset_index()

# %%
sofa_all_df['category'].value_counts()
# Out:
# sofa        480
# loveseat    381
# sofa_bed    363
# futon       260
# dtype: int64

# %%
sofa_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1484 entries, 0 to 1483
# Data columns (total 16 columns):
# product_id              1484 non-null object
# category                1484 non-null object
# colors                  1484 non-null object
# description             1484 non-null object
# features                1484 non-null object
# image_links_all         1484 non-null object
# image_links_by_color    1484 non-null object
# manufacturer            1484 non-null object
# price                   1484 non-null object
# rating_avg              1049 non-null object
# rating_count            1049 non-null object
# specs                   1414 non-null object
# title                   1484 non-null object
# url                     1484 non-null object
# website                 1484 non-null object
# description_all         1484 non-null object
# dtypes: object(16)
# memory usage: 197.1+ KB

# %%
coffee_table_df = coffee_table_df[coffee_table_df.index != 336]
desk_df = desk_df[desk_df.index != 768]
dining_table_df = dining_table_df[dining_table_df.index != 43]
dining_table_df = dining_table_df[dining_table_df.index != 669]
dining_table_df = dining_table_df[dining_table_df.index != 8]
nightstand_df = nightstand_df[nightstand_df.index != 864]

# %% [markdown]
# ### Still some replicates in dining_chair_df. No replicates in any other dataframes.

# %%
sofa_all_df.to_json('wayfair/sofa_all.json')
coffee_table_df.to_json('wayfair/coffee_table.json')
desk_df.to_json('wayfair/desk.json')
office_chair_df.to_json('wayfair/office_chair.json')
bookcase_df.to_json('wayfair/bookcase.json')
dining_table_df.to_json('wayfair/dining_table.json')
dining_chair_df.to_json('wayfair/dining_chair.json')
bed_df.to_json('wayfair/bed.json')
nightstand_df.to_json('wayfair/nightstand.json')
dresser_df.to_json('wayfair/dresser.json')

# %% [markdown]
# ## Check price

# %%
print 'sofa'
print sofa_all_df['price'].shape
print sofa_all_df[sofa_all_df['price']<1000]['price'].shape
print 'coffee_table'
print coffee_table_df['price'].shape
print coffee_table_df[coffee_table_df['price']<500]['price'].shape
print 'desk'
print desk_df['price'].shape
print desk_df[desk_df['price']<500]['price'].shape
print 'office_chair'
print office_chair_df['price'].shape
print office_chair_df[office_chair_df['price']<500]['price'].shape
print 'bookcase'
print bookcase_df['price'].shape
print bookcase_df[bookcase_df['price']<500]['price'].shape
print 'dining_table'
print dining_table_df['price'].shape
print dining_table_df[dining_table_df['price']<700]['price'].shape
print 'dining_chair'
print dining_chair_df['price'].shape
print dining_chair_df[dining_chair_df['price']<500]['price'].shape
print 'bed'
print bed_df['price'].shape
print bed_df[bed_df['price']<700]['price'].shape
print 'nightstand'
print nightstand_df['price'].shape
print nightstand_df[nightstand_df['price']<500]['price'].shape
print 'dresser'
print dresser_df['price'].shape
print dresser_df[dresser_df['price']<700]['price'].shape
# Out:
# sofa
# (1484,)
# (1211,)
# coffee_table
# (1007,)
# (787,)
# desk
# (1007,)
# (711,)
# office_chair
# (1008,)
# (887,)
# bookcase
# (1008,)
# (812,)
# dining_table
# (1005,)
# (518,)
# dining_chair
# (1008,)
# (940,)
# bed
# (1008,)
# (682,)
# nightstand
# (1007,)
# (840,)
# dresser
# (1008,)
# (689,)

# %% [markdown]
# # Combine dining table&chair, office desk&chair:

# %%
desk_df = pd.read_json('wayfair/desk.json')
office_chair_df = pd.read_json('wayfair/office_chair.json')

dining_table_df = pd.read_json('wayfair/dining_table.json')
dining_chair_df = pd.read_json('wayfair/dining_chair.json')

# %%
office_df = pd.concat([desk_df, office_chair_df], axis=0)

# %%
office_df.reset_index(inplace=True)

# %%
office_df.drop('index', axis=1, inplace=True)

# %%
office_df.head(2)
# Out:
#   category colors                                        description  \
# 0     desk     []  Try this minimalist desk to create a workspace...
# 1     desk     []  The Bauman Computer Desk with Hutch is a comfo...
#
#                                      description_all  \
# 0  Try this minimalist desk to create a workspace...
# 1  The Bauman Computer Desk with Hutch is a comfo...
#
#                                             features  \
# 0  \nFeatures\n\nPull out storage drawer\nStorage...
# 1  \nFeatures\n\nMilled cherry finish\nSlide-out ...
#
#                                      image_links_all image_links_by_color  \
# 0  [https://secure.img1.wfrcdn.com/lf/49/hash/305...                   {}
# 1  [https://secure.img1.wfrcdn.com/lf/49/hash/309...                   {}
#
#      manufacturer   price product_id  rating_avg  rating_count  \
# 0  Zipcode Design  102.99   ZIPC1663         3.0            28
# 1     Three Posts  189.99   THRE1821         4.5             2
#
#                                                specs  \
# 0  \nWeights & Dimensions\n\n\n\n            Over...
# 1  \nWeights & Dimensions\n\n\n\n            Over...
#
#                              title  \
# 0                  Writing Desk II
# 1  Bauman Computer Desk with Hutch
#
#                                                  url  website
# 0  http://www.wayfair.com/Writing-Desk-II-ZIPC166...  wayfair
# 1  http://www.wayfair.com/Bauman-Computer-Desk-wi...  wayfair

# %%
dining_df = pd.concat([dining_table_df, dining_chair_df], axis=0)
dining_df.reset_index(inplace=True)
dining_df.drop('index', axis=1, inplace=True)
dining_df.head(2)
# Out:
#        category                                             colors  \
# 0  dining_table                               [Bisque, Dark Brown]
# 1  dining_table  [Amber Brown, Dark Chocolate, Cherry Walnut, C...
#
#                                          description  \
# 0
# 1  The Reagan Dining Table's classic simplicity m...
#
#                                      description_all  \
# 0  \n\nFeatures\n\nMestler collection\nMade in Ch...
# 1  The Reagan Dining Table's classic simplicity m...
#
#                                             features  \
# 0  \nFeatures\n\nMestler collection\nMade in Chin...
# 1  \nFeatures\n\nWipe with a clean, damp, lint-fr...
#
#                                      image_links_all  \
# 0  [https://secure.img1.wfrcdn.com/lf/49/hash/266...
# 1  [https://secure.img2.wfrcdn.com/lf/49/hash/250...
#
#                                 image_links_by_color  \
# 0  {u'Dark Brown': [u'https://secure.img1.wfrcdn....
# 1  {u'Classic Crimson': [u'https://secure.img2.wf...
#
#                  manufacturer    price product_id  rating_avg  rating_count  \
# 0  Signature Design by Ashley   420.99    GNT4711         4.5            15
# 1                  Birch Lane  1799.00     BL8027         NaN           NaN
#
#                                                specs  \
# 0  \nWeights & Dimensions\n\n\n\n            Over...
# 1  \nWeights & Dimensions\nLeaf\n\n\n            ...
#
#                                                title  \
# 0                               Mestler Dining Table
# 1  Reagan Extending Custom Dining Table, 46 x 76 ...
#
#                                                  url  website
# 0  http://www.wayfair.com/Mestler-Dining-Table-D5...  wayfair
# 1  http://www.wayfair.com/Reagan-46-x-76-Custom-D...  wayfair

# %%
office_df.to_json('wayfair/office.json')
dining_df.to_json('wayfair/dining.json')

# %% [markdown]
# # Now creating the pipeline for the tfidf of sofa_all & pickle

# %%
sofa_all_df = pd.read_json('wayfair/sofa_all.json')
X = sofa_all_df['description_all']
tfidf = TfidfVectorizer(strip_accents='unicode', stop_words='english', max_df=0.8, 
                        max_features=1000, ngram_range = (1,2))
tfidf_matrix = tfidf.fit_transform(X).todense()

# %%
start = time.time()
tfidf = TfidfVectorizer(strip_accents='unicode', stop_words='english', max_df=0.8, 
                        max_features=1000, ngram_range = (1,2))
tfidf_matrix = tfidf.fit_transform(X).todense()
print time.time() - start
# Out:
# 1.05737304688

# %%
tfidf_matrix.shape
# Out:
# (1484, 1000)

# %%
with open('wayfair/pickle/sofa_tfidf.pkl', 'w') as f:
    pickle.dump(tfidf, f)
with open('wayfair/pickle/sofa_tfidf_matrix.pkl', 'w') as f:
    pickle.dump(tfidf_matrix, f)

# %%
np.savetxt("wayfair/pickle/tfidf_matrix.csv", tfidf_matrix, delimiter=",")
